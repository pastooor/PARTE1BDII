# %% [markdown]
# #### PARTE 1

# %%
from neo4j import GraphDatabase

# Preparamos la sesión para acceder a neo4j
driver = GraphDatabase.driver('neo4j://localhost:7687', auth=("neo4j", "BDII2023"))
session = driver.session()

# %%
def search_monsters(room_name):
    query = """
    MATCH (r:Room {room_name: $room_name}) - [:CONTAINS] - (m:Monster) 
    MATCH (r2:Room) - [:CONTAINS] - (m)
    MATCH (r2) - [:CONTAINS] - (m2:Monster)
    RETURN DISTINCT m, m2
    """  

    results = session.run(query, room_name=room_name).data()
    monsters_dict = {}
    
    # Iterar sobre los resultados y construir el diccionario
    for record in results:
        m = (record['m']['name'], record['m']['monsters_id'])  # Clave como tupla de nombre e id
        m2 = {'name': record['m2']['name'], 'monsters_id': record['m2']['monsters_id']}  # Valor como diccionario con nombre e id
        
        # Si m no está en el diccionario, agregarlo con una lista vacía como valor
        if m not in monsters_dict:
            monsters_dict[m] = []
        
        # Agregar m2 a la lista correspondiente a m
        monsters_dict[m].append(m2)
        
    if monsters_dict == {}:
        print('Esta sala no tiene monstruos')
    else:      
        return monsters_dict

# %%
search_monsters('worried workshop ')
# Out:
# Esta sala no tiene monstruos

# %%
search_monsters('storage room of degenerates')
# Out:
# {('gargoyle', 1): [{'name': 'gargoyle', 'monsters_id': 1},
#   {'name': 'vampire spawn', 'monsters_id': 6},
#   {'name': 'doppelganger', 'monsters_id': 0},
#   {'name': 'wererat', 'monsters_id': 2},
#   {'name': 'revenant', 'monsters_id': 4},
#   {'name': 'thug', 'monsters_id': 13},
#   {'name': 'assassin', 'monsters_id': 9}],
#  ('wererat', 2): [{'name': 'wererat', 'monsters_id': 2},
#   {'name': 'vampire spawn', 'monsters_id': 6},
#   {'name': 'assassin', 'monsters_id': 9},
#   {'name': 'gargoyle', 'monsters_id': 1},
#   {'name': 'revenant', 'monsters_id': 4},
#   {'name': 'doppelganger', 'monsters_id': 0},
#   {'name': 'thug', 'monsters_id': 13}],
#  ('revenant', 4): [{'name': 'revenant', 'monsters_id': 4},
#   {'name': 'wererat', 'monsters_id': 2},
#   {'name': 'gargoyle', 'monsters_id': 1},
#   {'name': 'doppelganger', 'monsters_id': 0},
#   {'name': 'vampire spawn', 'monsters_id': 6}],
#  ('goblin boss', 143): [{'name': 'goblin boss', 'monsters_id': 143},
#   {'name': 'weretiger', 'monsters_id': 163},
#   {'name': 'scarecrow', 'monsters_id': 188},
#   {'name': 'orog', 'monsters_id': 175},
#   {'name': 'peryton', 'monsters_id': 178},
#   {'name': 'water weird', 'monsters_id': 199},
#   {'name': 'cyclops', 'monsters_id': 126},
#   {'name': 'faerie dragon g/b/i/v', 'monsters_id': 131},
#   {'name': 'thri-kreen', 'monsters_id': 195},
#   {'name': 'yuan-ti pureblood', 'monsters_id': 206},
#   {'name': 'hippogriff', 'monsters_id': 148},
#   {'name': 'harpy', 'monsters_id': 147},
#   {'name': 'cockatrice', 'monsters_id': 125},
#   {'name': 'yeti', 'monsters_id': 202},
#   {'name': 'gnoll pack lord', 'monsters_id': 140},
#   {'name': 'manticore', 'monsters_id': 165},
#   {'name': 'half-ogre', 'monsters_id': 170},
#   {'name': 'merrow', 'monsters_id': 167},
#   {'name': 'ogre', 'monsters_id': 169},
#   {'name': 'griffon', 'monsters_id': 144},
#   {'name': 'werewolf', 'monsters_id': 164},
#   {'name': 'gnoll fang of yeenoghu', 'monsters_id': 141},
#   {'name': 'owlbear', 'monsters_id': 176},
#   {'name': 'shambling mound', 'monsters_id': 189},
#   {'name': 'yuan-ti malison', 'monsters_id': 205},
#   {'name': 'faerie dragon r/o/y', 'monsters_id': 130},
#   {'name': 'bulette', 'monsters_id': 121},
#   {'name': 'pegasus', 'monsters_id': 177},
#   {'name': 'satyr', 'monsters_id': 187},
#   {'name': 'bandit captain', 'monsters_id': 208},
#   {'name': 'orc eye of gruumsh', 'monsters_id': 174}],
#  ('pegasus', 177): [{'name': 'pegasus', 'monsters_id': 177},
#   {'name': 'bulette', 'monsters_id': 121},
#   {'name': 'bugbear', 'monsters_id': 119},
#   {'name': 'thri-kreen', 'monsters_id': 195},
#   {'name': 'scout', 'monsters_id': 209},
#   {'name': 'bandit captain', 'monsters_id': 208},
#   {'name': 'ogre', 'monsters_id': 169},
#   {'name': 'nightmare', 'monsters_id': 168},
#   {'name': 'will-o-wisp', 'monsters_id': 200},
#   {'name': 'faerie dragon r/o/y', 'monsters_id': 130},
#   {'name': 'hill giant', 'monsters_id': 136},
#   {'name': 'chimera', 'monsters_id': 124},
#   {'name': 'griffon', 'monsters_id': 144},
#   {'name': 'centaur', 'monsters_id': 123},
#   {'name': 'wyvern', 'monsters_id': 201},
#   {'name': 'shambling mound', 'monsters_id': 189},
#   {'name': 'orc war chief', 'monsters_id': 173},
#   {'name': 'displacer beast', 'monsters_id': 127},
#   {'name': 'lizardfolk royal', 'monsters_id': 160},
#   {'name': 'satyr', 'monsters_id': 187},
#   {'name': 'goblin boss', 'monsters_id': 143},
#   {'name': 'unicorn', 'monsters_id': 198},
#   {'name': 'harpy', 'monsters_id': 147},
#   {'name': 'cloud giant', 'monsters_id': 133},
#   {'name': 'water weird', 'monsters_id': 199},
#   {'name': 'weretiger', 'monsters_id': 163},
#   {'name': 'faerie dragon g/b/i/v', 'monsters_id': 131},
#   {'name': 'lizardfolk shaman', 'monsters_id': 159},
#   {'name': 'yeti', 'monsters_id': 202},
#   {'name': 'werewolf', 'monsters_id': 164},
#   {'name': 'peryton', 'monsters_id': 178},
#   {'name': 'yuan-ti abomination', 'monsters_id': 204},
#   {'name': 'yuan-ti malison', 'monsters_id': 205},
#   {'name': 'ettin', 'monsters_id': 129},
#   {'name': 'troll', 'monsters_id': 197},
#   {'name': 'sahuagin priestess', 'monsters_id': 185},
#   {'name': 'yuan-ti pureblood', 'monsters_id': 206},
#   {'name': 'wereboar', 'monsters_id': 162},
#   {'name': 'owlbear', 'monsters_id': 176},
#   {'name': 'half-ogre', 'monsters_id': 170},
#   {'name': 'cockatrice', 'monsters_id': 125},
#   {'name': 'sahuagin', 'monsters_id': 184},
#   {'name': 'orog', 'monsters_id': 175},
#   {'name': 'orc', 'monsters_id': 172}],
#  ('sahuagin priestess',
#   185): [{'name': 'sahuagin priestess', 'monsters_id': 185}, {'name': 'yeti',
#    'monsters_id': 202}, {'name': 'werebear',
#    'monsters_id': 161}, {'name': 'peryton', 'monsters_id': 178}, {'name': 'sahuagin baron',
#    'monsters_id': 186}, {'name': 'hobgoblin captain',
#    'monsters_id': 150}, {'name': 'wereboar', 'monsters_id': 162}, {'name': 'bandit captain',
#    'monsters_id': 208}, {'name': 'half-dragon',
#    'monsters_id': 146}, {'name': 'gnoll pack lord', 'monsters_id': 140}, {'name': 'orc eye of gruumsh',
#    'monsters_id': 174}, {'name': 'lizardfolk shaman',
#    'monsters_id': 159}, {'name': 'harpy', 'monsters_id': 147}, {'name': 'scarecrow',
#    'monsters_id': 188}, {'name': 'faerie dragon r/o/y',
#    'monsters_id': 130}, {'name': 'jackalwere', 'monsters_id': 153}, {'name': 'merrow',
#    'monsters_id': 167}, {'name': 'galeb duhr',
#    'monsters_id': 132}, {'name': 'pegasus', 'monsters_id': 177}, {'name': 'hippogriff',
#    'monsters_id': 148}, {'name': 'half-ogre',
#    'monsters_id': 170}, {'name': 'ettin', 'monsters_id': 129}, {'name': 'troll',
#    'monsters_id': 197}, {'name': 'ogre',
#    'monsters_id': 169}, {'name': 'gnoll fang of yeenoghu', 'monsters_id': 141}, {'name': 'displacer beast',
#    'monsters_id': 127}, {'name': 'griffon',
#    'monsters_id': 144}, {'name': 'orog', 'monsters_id': 175}, {'name': 'yuan-ti pureblood',
#    'monsters_id': 206}, {'name': 'unicorn',
#    'monsters_id': 198}, {'name': 'yuan-ti malison', 'monsters_id': 205}, {'name': 'lizardfolk',
#    'monsters_id': 158}, {'name': 'orc war chief',
#    'monsters_id': 173}, {'name': 'wyvern', 'monsters_id': 201}, {'name': 'shambling mound',
#    'monsters_id': 189}],
#  ('satyr', 187): [{'name': 'satyr', 'monsters_id': 187},
#   {'name': 'manticore', 'monsters_id': 165},
#   {'name': 'scarecrow', 'monsters_id': 188},
#   {'name': 'lizardfolk', 'monsters_id': 158},
#   {'name': 'faerie dragon r/o/y', 'monsters_id': 130},
#   {'name': 'pegasus', 'monsters_id': 177},
#   {'name': 'goblin boss', 'monsters_id': 143},
#   {'name': 'owlbear', 'monsters_id': 176},
#   {'name': 'lizardfolk shaman', 'monsters_id': 159},
#   {'name': 'bugbear', 'monsters_id': 119},
#   {'name': 'hobgoblin', 'monsters_id': 149}],
#  ('yuan-ti malison', 205): [{'name': 'yuan-ti malison', 'monsters_id': 205},
#   {'name': 'merrow', 'monsters_id': 167},
#   {'name': 'orog', 'monsters_id': 175},
#   {'name': 'unicorn', 'monsters_id': 198},
#   {'name': 'will-o-wisp', 'monsters_id': 200},
#   {'name': 'weretiger', 'monsters_id': 163},
#   {'name': 'orc war chief', 'monsters_id': 173},
#   {'name': 'werewolf', 'monsters_id': 164},
#   {'name': 'cyclops', 'monsters_id': 126},
#   {'name': 'sahuagin priestess', 'monsters_id': 185},
#   {'name': 'cockatrice', 'monsters_id': 125},
#   {'name': 'harpy', 'monsters_id': 147},
#   {'name': 'lizardfolk shaman', 'monsters_id': 159},
#   {'name': 'yuan-ti abomination', 'monsters_id': 204},
#   {'name': 'scout', 'monsters_id': 209},
#   {'name': 'lizardfolk', 'monsters_id': 158},
#   {'name': 'gnoll', 'monsters_id': 139},
#   {'name': 'yuan-ti pureblood', 'monsters_id': 206},
#   {'name': 'faerie dragon g/b/i/v', 'monsters_id': 131},
#   {'name': 'gnoll pack lord', 'monsters_id': 140},
#   {'name': 'troll', 'monsters_id': 197},
#   {'name': 'yeti', 'monsters_id': 202},
#   {'name': 'scarecrow', 'monsters_id': 188},
#   {'name': 'goblin boss', 'monsters_id': 143},
#   {'name': 'faerie dragon r/o/y', 'monsters_id': 130},
#   {'name': 'water weird', 'monsters_id': 199},
#   {'name': 'thri-kreen', 'monsters_id': 195},
#   {'name': 'sahuagin baron', 'monsters_id': 186},
#   {'name': 'wereboar', 'monsters_id': 162},
#   {'name': 'orc eye of gruumsh', 'monsters_id': 174},
#   {'name': 'nightmare', 'monsters_id': 168},
#   {'name': 'griffon', 'monsters_id': 144},
#   {'name': 'owlbear', 'monsters_id': 176},
#   {'name': 'young remorhaz', 'monsters_id': 182},
#   {'name': 'bugbear chief', 'monsters_id': 120},
#   {'name': 'manticore', 'monsters_id': 165},
#   {'name': 'pegasus', 'monsters_id': 177}]}

# %% [markdown]
# #### PARTE 2

# %%
from graphdatascience import GraphDataScience
import pandas as pd

# configure connection
gds = GraphDataScience("neo4j://localhost:7687", auth=("neo4j", "BDII2023"))
print(f"GDS version: {gds.version()}")
# Out:
# GDS version: 2.6.5

# %%
def monster_recommendations(room_name):
    node_query = """
    MATCH (r1:Room)-[:CONTAINS]->(m1:Monster)<-[:CONTAINS]-(r2:Room)-[:CONTAINS]->(m2:Monster)
    RETURN DISTINCT id(m1) as id
    """
    edge_query = """
    MATCH (r1:Room)-[:CONTAINS]->(m1:Monster)<-[:CONTAINS]-(r2:Room)-[:CONTAINS]->(m2:Monster)
    RETURN DISTINCT id(m1) as source, id(m2) as target, 1 as weight
    """

    with gds.graph.project.cypher("monster_coappearances", node_query, edge_query) as g_temp:
        q_source = """
            MATCH (:Room {room_name: $room_name})-[:CONTAINS]->(m:Monster) 
            RETURN id(m) as sources
        """
        sources = gds.run_cypher(q_source, params={"room_name": room_name}).iloc[:, 0]
        # print(sources)
        result = gds.pageRank.stream(g_temp, sourceNodes=sources, relationshipWeightProperty="weight")
        result = result.query("score > 0")

        nodes = result.nodeId.to_list()
        q = """
        MATCH (:Room {room_name: $room_name})-[:CONTAINS]->(m:Monster) WITH collect(m) as sources
        MATCH (m:Monster) WHERE id(m) IN $nodes AND NOT(m in sources) 
        RETURN id(m) AS nodeId, m.name AS monster
        """
        df = gds.run_cypher(q, params={"room_name": room_name, "nodes": nodes})

        recommendation = pd.merge(result, df, how="left", left_on="nodeId", right_on="nodeId").dropna().sort_values("score", ascending=False).head(5)

    return recommendation

# %%
monster_recommendations(room_name='storage room of degenerates')
# Out:
#     nodeId     score        monster
# 0    11211  0.460563   doppelganger
# 4    11217  0.326443  vampire spawn
# 5    11220  0.231330       assassin
# 6    11224  0.231330           thug
# 63   11399  0.111986      scarecrow
